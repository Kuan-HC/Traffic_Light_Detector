# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
# %matplotlib inline

# %%
from Traffic_Light import TLClassifier

# %%
detect = TLClassifier()
# Out:
# model loaded

# %%
image = cv2.imread("test_image/traffic_light_4.jpg")
image2 = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image2)

# %%
detect.get_classification(image)
# Out:
# This groupb brightness value:  4.313802083333333
# RED
# 0
